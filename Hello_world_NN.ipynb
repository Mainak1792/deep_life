# %% [markdown]
# <a href="https://colab.research.google.com/github/Mainak1792/deep_life/blob/main/Hello_world_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def a(x):
    y= 2*x-1
    return(y)

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model=tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
x = np.array([-1.0,0.0,1.0,2.0,3.0,4.0], dtype= float)
y = np.array([-1.0,0.0,1.0,2.0,3.0,4.0], dtype= float)

# %%
model.fit(x, y, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 427ms/step - loss: 0.1075
# Epoch 2/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0848
# Epoch 3/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0669
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0528
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0417
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0330
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0261
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0207
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0165
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0131
# Epoch 11/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0105
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0084
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[9.999477]]
